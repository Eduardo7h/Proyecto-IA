# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Importamos el csv 
df = pd.read_csv('mxmh_survey_results (1).csv')

# Creamos una copia del data 
cp_df = df.copy()
cp_df
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# ...

# %%
print(cp_df.shape)
# Out:
# (736, 33)

# %%
## Creamos una funcion que

# %%
filas_nan = df[df.isna().any(axis=1)]
print(filas_nan)
# Out:
#               Timestamp   Age  Hours per day While working Instrumentalist  \
# 0    8/27/2022 19:29:02  18.0            3.0           Yes             Yes
# 1    8/27/2022 19:57:31  63.0            1.5           Yes              No
# 10   8/27/2022 22:51:15  18.0            3.0           Yes             Yes
# 12   8/27/2022 23:04:00   NaN            3.0           Yes              No
# 15   8/27/2022 23:19:52  17.0            2.0            No              No
# ..                  ...   ...            ...           ...             ...
# 688   9/24/2022 0:42:39  18.0            4.0           Yes              No
# 700  10/3/2022 10:00:01  20.0            1.0           Yes              No
# 706  10/3/2022 15:38:19  23.0            1.0           Yes             Yes
# 712   10/4/2022 8:53:39  23.0            3.0           Yes              No
# 717  10/5/2022 12:30:23  23.0            2.0            No              No
#
#     Composer Fav genre Exploratory Foreign languages    BPM  ...  \
# ...

# %%
import matplotlib.pylab as plt 
import missingno as msmo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import matplotlib.pylab as plt
# ----> 2 import missingno as msmo
#
# ModuleNotFoundError: No module named 'missingno'
